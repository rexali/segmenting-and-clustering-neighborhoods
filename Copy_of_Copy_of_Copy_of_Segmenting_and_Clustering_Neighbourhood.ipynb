# %% [markdown]
# <a href="https://colab.research.google.com/github/rexali/segmenting-and-clustering-neighborhoods/blob/master/Copy_of_Copy_of_Copy_of_Segmenting_and_Clustering_Neighbourhood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
from tabulate import tabulate

# %%
res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
table_df = pd.read_html(str(table))
df = table_df[0]
df[ df['Borough']!='Not assigned' ] 
df[ df['Neighbourhood']!='Not assigned' ]

df.groupby('Postcode', sort=False).agg(','.join)
df = df.groupby('Postcode').agg({'Borough': 'first',
                                 'Neighbourhood':','.join }).reset_index()
df[df['Borough']!='Not assigned']
df[df['Neighbourhood']!='Not assigned']
# Out:
#     Postcode  ...                                      Neighbourhood
# 1        M1B  ...                                      Rouge,Malvern
# 2        M1C  ...               Highland Creek,Rouge Hill,Port Union
# 3        M1E  ...                    Guildwood,Morningside,West Hill
# 4        M1G  ...                                             Woburn
# 5        M1H  ...                                          Cedarbrae
# 6        M1J  ...                                Scarborough Village
# 7        M1K  ...          East Birchmount Park,Ionview,Kennedy Park
# 8        M1L  ...                      Clairlea,Golden Mile,Oakridge
# 9        M1M  ...      Cliffcrest,Cliffside,Scarborough Village West
# 10       M1N  ...                         Birch Cliff,Cliffside West
# 11       M1P  ...  Dorset Park,Scarborough Town Centre,Wexford He...
# 12       M1R  ...                                   Maryvale,Wexford
# 13       M1S  ...                                          Agincourt
# ...

# %%
L = ['Thanks You', 'Its fine no problem', 'Are you sure']

#create new df 
dg = pd.DataFrame({'col':L})
print (dg)
